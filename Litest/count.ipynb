# %%
import glob

folder_path = "../runs/detect/exp/labels/"
all_txt_files = glob.glob(folder_path + "*.txt")

for txt_file in all_txt_files:
    with open(txt_file, "r") as file:
        lines = file.readlines()

    print(txt_file)
    # 儲存 bounding box 的 x_center 座標
    x_centers = []
    y_centers = []

    # 解析每一行標註
    for line in lines:
        class_label, x_center, y_center, width, height = map(float, line.split())

        x_centers.append(x_center)
        y_centers.append(y_center)


    # 將 y_center 座標排序
    y_centers.sort()
    x_centers.sort()

    # 初始化計數器
    x_group_count = 0
    y_group_count = 0

    x_group_tolerance = 0.1  # x分組容忍度
    y_group_tolerance = 0.02  # y分組容忍度

    x_current_group = [x_centers[0]]  # 目前的分組
    y_current_group = [y_centers[0]]  # 目前的分組

    # 檢查 x_center 座標是否接近彼此的 bounding box
    for i in range(1, len(x_centers)):
        if abs(x_centers[i] - x_current_group[-1]) <= x_group_tolerance:
            x_current_group.append(x_centers[i])  # 將 x_center 加入目前的分組
        else:
            x_group_count += 1
            print(f"Group {x_group_count}: {x_current_group}")  # 印出目前的分組
            x_current_group = [x_centers[i]]  # 開始新的分組

    # 印出最後一組
    if x_current_group:
        x_group_count += 1
        print(f"Group {x_group_count}: {x_current_group}")

    print("共有", x_group_count, "組 bounding box 的 x_center 座標接近。")

    # 檢查 y_center 座標是否接近彼此的 bounding box
    for i in range(1, len(y_centers)):
        if abs(y_centers[i] - y_current_group[-1]) <= y_group_tolerance:
            y_current_group.append(y_centers[i])  # 將 x_center 加入目前的分組
        else:
            y_group_count += 1
            print(f"Group {y_group_count}: {y_current_group}")  # 印出目前的分組
            y_current_group = [y_centers[i]]  # 開始新的分組

    # 印出最後一組
    if y_current_group:
        y_group_count += 1
        print(f"Group {y_group_count}: {y_current_group}")
        
    print("共有", y_group_count, "組 bounding box 的 y_center 座標接近。")
# Out:
# ../runs/detect/exp/labels\1.txt
# Group 1: [0.185547, 0.205078, 0.220703, 0.230469]
# Group 2: [0.548828, 0.599609, 0.652344, 0.685547]
# 共有 2 組 bounding box 的 x_center 座標接近。
# Group 1: [0.193359, 0.207031]
# Group 2: [0.375, 0.382812]
# Group 3: [0.558594, 0.5625]
# Group 4: [0.806641, 0.808594]
# 共有 4 組 bounding box 的 y_center 座標接近。
# ../runs/detect/exp/labels\10.txt
# Group 1: [0.0488281]
# Group 2: [0.236328, 0.259766, 0.265625]
# Group 3: [0.634766, 0.660156, 0.669922]
# 共有 3 組 bounding box 的 x_center 座標接近。
# Group 1: [0.34375, 0.34375]
# Group 2: [0.488281]
# Group 3: [0.523438, 0.535156]
# Group 4: [0.732422, 0.732422]
# 共有 4 組 bounding box 的 y_center 座標接近。
# ../runs/detect/exp/labels\11.txt
# Group 1: [0.234375, 0.263672, 0.273438]
# Group 2: [0.646484, 0.673828, 0.755859, 0.757812]
# 共有 2 組 bounding box 的 x_center 座標接近。
# Group 1: [0.173828]
# Group 2: [0.322266]
# Group 3: [0.367188]
# Group 4: [0.568359, 0.574219]
# Group 5: [0.798828, 0.802734]
# 共有 5 組 bounding box 的 y_center 座標接近。
# ../runs/detect/exp/labels\12.txt
# Group 1: [0.238281, 0.242188, 0.322266, 0.349609]
# Group 2: [0.716797, 0.738281, 0.765625]
# 共有 2 組 bounding box 的 x_center 座標接近。
# Group 1: [0.177734]
# Group 2: [0.324219]
# Group 3: [0.367188]
# Group 4: [0.570312, 0.576172]
# Group 5: [0.802734, 0.806641]
# 共有 5 組 bounding box 的 y_center 座標接近。
# ../runs/detect/exp/labels\13.txt
# Group 1: [0.158203, 0.167969]
# Group 2: [0.433594, 0.435547]
# Group 3: [0.705078, 0.710938]
# Group 4: [0.898438, 0.898438]
# 共有 4 組 bounding box 的 x_center 座標接近。
# Group 1: [0.525391, 0.539062, 0.556641, 0.564453]
# Group 2: [0.769531, 0.775391, 0.785156, 0.787109]
# 共有 2 組 bounding box 的 y_center 座標接近。
# ../runs/detect/exp/labels\14.txt
# Group 1: [0.0976562, 0.101562]
# Group 2: [0.244141, 0.259766, 0.291016]
# Group 3: [0.566406, 0.568359]
# Group 4: [0.832031, 0.837891]
# 共有 4 組 bounding box 的 x_center 座標接近。
# Group 1: [0.521484, 0.539062, 0.542969, 0.546875, 0.5625]
# Group 2: [0.773438, 0.777344, 0.785156, 0.791016]
# 共有 2 組 bounding box 的 y_center 座標接近。
# ../runs/detect/exp/labels\15.txt
# Group 1: [0.160156, 0.166016, 0.179688]
# Group 2: [0.460938, 0.470703, 0.478516]
# Group 3: [0.783203, 0.789062, 0.796875]
# 共有 3 組 bounding box 的 x_center 座標接近。
# Group 1: [0.367188, 0.367188, 0.373047]
# Group 2: [0.539062, 0.539062, 0.544922]
# Group 3: [0.734375, 0.734375, 0.736328]
# 共有 3 組 bounding box 的 y_center 座標接近。
# ../runs/detect/exp/labels\16.txt
# Group 1: [0.207031, 0.212891, 0.21875]
# Group 2: [0.519531, 0.533203, 0.544922]
# Group 3: [0.826172, 0.835938, 0.84375]
# 共有 3 組 bounding box 的 x_center 座標接近。
# Group 1: [0.369141, 0.373047, 0.375]
# Group 2: [0.539062, 0.541016, 0.544922]
# Group 3: [0.734375, 0.734375, 0.734375]
# 共有 3 組 bounding box 的 y_center 座標接近。
# ../runs/detect/exp/labels\17.txt
# Group 1: [0.212891, 0.228516, 0.253906]
# Group 2: [0.556641, 0.560547, 0.560547]
# Group 3: [0.837891, 0.839844, 0.847656]
# 共有 3 組 bounding box 的 x_center 座標接近。
# Group 1: [0.355469, 0.365234, 0.384766]
# Group 2: [0.585938, 0.585938, 0.589844]
# Group 3: [0.808594, 0.808594, 0.810547]
# 共有 3 組 bounding box 的 y_center 座標接近。
# ../runs/detect/exp/labels\18.txt
# Group 1: [0.154297, 0.160156, 0.167969]
# Group 2: [0.441406, 0.443359, 0.443359]
# Group 3: [0.746094, 0.777344, 0.789062]
# 共有 3 組 bounding box 的 x_center 座標接近。
# Group 1: [0.355469, 0.365234, 0.382812]
# Group 2: [0.587891, 0.587891, 0.591797]
# Group 3: [0.804688, 0.810547, 0.8125]
# 共有 3 組 bounding box 的 y_center 座標接近。
# ../runs/detect/exp/labels\19.txt
# Group 1: [0.236328, 0.242188, 0.248047]
# Group 2: [0.710938, 0.720703]
# 共有 2 組 bounding box 的 x_center 座標接近。
# Group 1: [0.357422]
# Group 2: [0.529297, 0.541016]
# Group 3: [0.796875, 0.796875]
# 共有 3 組 bounding box 的 y_center 座標接近。
# ../runs/detect/exp/labels\2.txt
# Group 1: [0.3125, 0.351562, 0.396484, 0.451172]
# Group 2: [0.769531, 0.779297, 0.792969, 0.814453]
# 共有 2 組 bounding box 的 x_center 座標接近。
# Group 1: [0.193359, 0.207031]
# Group 2: [0.373047, 0.378906]
# Group 3: [0.558594, 0.5625]
# Group 4: [0.804688, 0.810547]
# 共有 4 組 bounding box 的 y_center 座標接近。
# ../runs/detect/exp/labels\20.txt
# Group 1: [0.28125, 0.289062]
# Group 2: [0.738281, 0.755859, 0.759766]
# 共有 2 組 bounding box 的 x_center 座標接近。
# Group 1: [0.357422]
# Group 2: [0.53125, 0.541016]
# Group 3: [0.798828, 0.802734]
# 共有 3 組 bounding box 的 y_center 座標接近。
# ../runs/detect/exp/labels\21.txt
# Group 1: [0.369141, 0.384766, 0.408203]
# Group 2: [0.794922, 0.806641, 0.8125]
# 共有 2 組 bounding box 的 x_center 座標接近。
# Group 1: [0.259766, 0.273438]
# Group 2: [0.441406, 0.453125]
# Group 3: [0.648438, 0.666016]
# 共有 3 組 bounding box 的 y_center 座標接近。
# ../runs/detect/exp/labels\22.txt
# Group 1: [0.1875, 0.193359, 0.201172]
# Group 2: [0.595703, 0.623047, 0.636719]
# 共有 2 組 bounding box 的 x_center 座標接近。
# Group 1: [0.259766, 0.271484]
# Group 2: [0.439453, 0.453125]
# Group 3: [0.644531]
# Group 4: [0.666016]
# 共有 4 組 bounding box 的 y_center 座標接近。
# ../runs/detect/exp/labels\3.txt
# Group 1: [0.222656, 0.226562, 0.228516]
# Group 2: [0.675781, 0.681641, 0.701172]
# 共有 2 組 bounding box 的 x_center 座標接近。
# Group 1: [0.166016, 0.175781]
# Group 2: [0.404297, 0.423828]
# Group 3: [0.677734, 0.681641]
# 共有 3 組 bounding box 的 y_center 座標接近。
# ../runs/detect/exp/labels\4.txt
# Group 1: [0.298828, 0.304688, 0.306641]
# Group 2: [0.769531, 0.773438, 0.773438]
# 共有 2 組 bounding box 的 x_center 座標接近。
# Group 1: [0.162109, 0.175781]
# Group 2: [0.408203, 0.421875]
# Group 3: [0.675781, 0.683594]
# 共有 3 組 bounding box 的 y_center 座標接近。
# ../runs/detect/exp/labels\5.txt
# Group 1: [0.378906, 0.402344]
# Group 2: [0.773438, 0.777344]
# 共有 2 組 bounding box 的 x_center 座標接近。
# Group 1: [0.462891]
# Group 2: [0.484375]
# Group 3: [0.722656, 0.726562]
# 共有 3 組 bounding box 的 y_center 座標接近。
# ../runs/detect/exp/labels\7.txt
# Group 1: [0.285156, 0.289062, 0.294922]
# Group 2: [0.738281, 0.765625, 0.767578]
# 共有 2 組 bounding box 的 x_center 座標接近。
# Group 1: [0.324219]
# Group 2: [0.359375]
# Group 3: [0.546875, 0.548828]
# Group 4: [0.794922, 0.806641]
# 共有 4 組 bounding box 的 y_center 座標接近。
# ../runs/detect/exp/labels\8.txt
# Group 1: [0.226562, 0.234375, 0.269531]
# Group 2: [0.697266, 0.705078, 0.707031]
# 共有 2 組 bounding box 的 x_center 座標接近。
# Group 1: [0.326172]
# Group 2: [0.359375]
# Group 3: [0.544922, 0.548828]
# Group 4: [0.787109, 0.806641]
# 共有 4 組 bounding box 的 y_center 座標接近。
# ../runs/detect/exp/labels\9.txt
# Group 1: [0.324219, 0.339844, 0.365234]
# Group 2: [0.736328, 0.740234, 0.761719]
# Group 3: [0.955078]
# 共有 3 組 bounding box 的 x_center 座標接近。
# Group 1: [0.341797, 0.345703]
# Group 2: [0.492188]
# Group 3: [0.527344, 0.537109]
# Group 4: [0.732422, 0.734375]
# 共有 4 組 bounding box 的 y_center 座標接近。
# ../runs/detect/exp/labels\bus.txt
# Group 1: [0.458025, 0.474074]
# Group 2: [0.619136, 0.680864]
# Group 3: [0.864198]
# 共有 3 組 bounding box 的 x_center 座標接近。
# Group 1: [0.0203704, 0.0222222, 0.0421296, 0.0574074]
# Group 2: [0.166667]
# 共有 2 組 bounding box 的 y_center 座標接近。
# ../runs/detect/exp/labels\street_view_0.txt
# Group 1: [0.065625, 0.0882813, 0.11875]
# Group 2: [0.225]
# Group 3: [0.373437]
# 共有 3 組 bounding box 的 x_center 座標接近。
# Group 1: [0.124219]
# Group 2: [0.202344, 0.209375]
# Group 3: [0.267969]
# Group 4: [0.425]
# 共有 4 組 bounding box 的 y_center 座標接近。
# ../runs/detect/exp/labels\street_view_1.txt
# Group 1: [0.795313]
# Group 2: [0.942969]
# 共有 2 組 bounding box 的 x_center 座標接近。
# Group 1: [0.741406, 0.754687]
# 共有 1 組 bounding box 的 y_center 座標接近。
# ../runs/detect/exp/labels\street_view_2.txt
# Group 1: [0.0476562]
# 共有 1 組 bounding box 的 x_center 座標接近。
# Group 1: [0.659375]
# 共有 1 組 bounding box 的 y_center 座標接近。
# ../runs/detect/exp/labels\street_view_3.txt
# Group 1: [0.110937]
# Group 2: [0.421094, 0.424219]
# Group 3: [0.582031, 0.604688]
# Group 4: [0.800781, 0.896094, 0.966406]
# 共有 4 組 bounding box 的 x_center 座標接近。
# Group 1: [0.357031, 0.359375, 0.363281]
# Group 2: [0.421094]
# Group 3: [0.544531, 0.545313]
# Group 4: [0.692187]
# Group 5: [0.835938]
# 共有 5 組 bounding box 的 y_center 座標接近。
